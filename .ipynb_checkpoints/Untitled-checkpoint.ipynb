# %%
import pandas as pd
import requests
import time
import os
import json
import pprint
import nvdlib

def cvss_online(cve_id):
    try:
        cve = nvdlib.searchCVE(cveId=cve_id)[0]
    except IndexError:
        return "Invalid CVE ID"
    
    description = v2score = v2exploitability = v2severity = v2impactScore = 'NF'
    accessVector = accessComplexity = authentication = confidentialityImpact = integrityImpact = availabilityImpact = 'NF'
    
    try:
        description = cve.descriptions[0].value
    except AttributeError:
        pass
    
    try:
        v2score = cve.v2score
    except AttributeError:
        pass
    
    try:
        v2exploitability = cve.v2exploitability
    except AttributeError:
        pass
    
    try:
        v2severity = cve.v2severity
    except AttributeError:
        pass
    
    try:
        v2impactScore = cve.v2impactScore
    except AttributeError:
        pass
    
    try:
        cvss_data = cve.metrics.cvssMetricV2[0].cvssData
        accessVector = cvss_data.accessVector
        accessComplexity = cvss_data.accessComplexity
        authentication = cvss_data.authentication
        confidentialityImpact = cvss_data.confidentialityImpact
        integrityImpact = cvss_data.integrityImpact
        availabilityImpact = cvss_data.availabilityImpact
    except AttributeError:
        pass
    
    return {
        "cve":cve_id,
        "description": description,
        "baseScore": v2score,
        "exploitabilityScore": v2exploitability,
        "severity": v2severity,
        "impactScore": v2impactScore,
        "accessVector": accessVector,
        "accessComplexity": accessComplexity,
        "authentication": authentication,
        "confidentialityImpact": confidentialityImpact,
        "integrityImpact": integrityImpact,
        "availabilityImpact": availabilityImpact
    }

# %%
df = pd.read_csv('./data/scan_results/sockshop.csv')
db = pd.read_csv('./data/cve_id_db.csv',low_memory=False)
dfn = df.loc[~df['cve'].isin(db['cve']),['cve']]
dfn = dfn.drop_duplicates()
dfn = dfn['cve'].tolist()
dfn
new_cves = []
for cve in dfn:
    cve_info = cvss_online(cve)
    if cve_info != "Invalid CVE ID" or cve_info['description'] !='NF' :
        new_cves.append(cve_info)
print(cve_info)

#     # Convert new_cves list to a DataFrame and append it to the database
#     new_cves_df = pd.DataFrame(new_cves)
#     db = pd.concat([db, new_cves_df], ignore_index=True)

#     return db
# Out:
# {'description': "Issue summary: Checking excessively long DH keys or parameters may be very slow.\n\nImpact summary: Applications that use the functions DH_check(), DH_check_ex()\nor EVP_PKEY_param_check() to check a DH key or DH parameters may experience long\ndelays. Where the key or parameters that are being checked have been obtained\nfrom an untrusted source this may lead to a Denial of Service.\n\nThe function DH_check() performs various checks on DH parameters. One of those\nchecks confirms that the modulus ('p' parameter) is not too large. Trying to use\na very large modulus is slow and OpenSSL will not normally use a modulus which\nis over 10,000 bits in length.\n\nHowever the DH_check() function checks numerous aspects of the key or parameters\nthat have been supplied. Some of those checks use the supplied modulus value\neven if it has already been found to be too large.\n\nAn application that calls DH_check() and supplies a key or parameters obtained\nfrom an untrusted source could be vulernable to a Denial of Service attack.\n\nThe function DH_check() is itself called by a number of other OpenSSL functions.\nAn application calling any of those other functions may similarly be affected.\nThe other functions affected by this are DH_check_ex() and\nEVP_PKEY_param_check().\n\nAlso vulnerable are the OpenSSL dhparam and pkeyparam command line applications\nwhen using the '-check' option.\n\nThe OpenSSL SSL/TLS implementation is not affected by this issue.\nThe OpenSSL 3.0 and 3.1 FIPS providers are not affected by this issue.", 'v2score': 'NF', 'v2exploitability': 'NF', 'v2severity': 'NF', 'v2impactScore': 'NF', 'accessVector': 'NF', 'accessComplexity': 'NF', 'authentication': 'NF', 'confidentialityImpact': 'NF', 'integrityImpact': 'NF', 'availabilityImpact': 'NF'}

# %%
new_cves_df = pd.DataFrame(new_cves)
new_cves_df
# Out:
#                                           description v2score  \
# 0   Two errors in the "asn1_find_node()" function ...     6.8
# 1   A deserialization flaw was discovered in jacks...      NF
# 2   In FasterXML jackson-databind before 2.14.0-rc...      NF
# 3   In FasterXML jackson-databind before 2.13.4, r...      NF
# 4   If Apache Tomcat 8.5.0 to 8.5.82, 9.0.0-M1 to ...      NF
# 5   The URL pattern of "" (the empty string) which...     4.3
# 6   When using the RemoteIpFilter with requests re...      NF
# 7   The simplified implementation of blocking read...      NF
# 8   In Spring Boot versions 3.0.0 - 3.0.6, 2.7.0 -...      NF
# 9   \nReactive web applications that use Spring HA...      NF
# 10  In Spring Framework versions 6.0.0 - 6.0.6, 5....      NF
# 11  In spring framework versions prior to 5.2.24 r...      NF
# 12  SnakeYaml's Constructor() class does not restr...      NF
# 13  The package org.yaml:snakeyaml from 0 and befo...      NF
# 14  Using snakeYAML to parse untrusted YAML files ...      NF
# 15  Using snakeYAML to parse untrusted YAML files ...      NF
# 16  Using snakeYAML to parse untrusted YAML files ...      NF
# 17  Using snakeYAML to parse untrusted YAML files ...      NF
# 18  Those using Snakeyaml to parse untrusted YAML ...      NF
# 19  A flaw was found in the bash package, where a ...      NF
# 20  GnuPG can be made to spin on a relatively smal...      NF
# 21  An improper certificate validation vulnerabili...      NF
# 22  An information disclosure vulnerability exists...      NF
# 23  A vulnerability was found in openldap. This se...      NF
# 24  SQLite through 3.40.0, when relying on --safe ...      NF
# 25  Issue summary: The AES-SIV cipher implementati...      NF
# 26  ** DISPUTED ** An issue was discovered in syst...      NF
# 27  ** DISPUTED ** An issue was discovered in syst...      NF
# 28  ** DISPUTED ** An issue was discovered in syst...      NF
# 29  A vulnerability was found in zstd v1.4.10, whe...      NF
# 30  In Shadow 4.13, it is possible to inject contr...      NF
# 31  runc through 1.1.4 has Incorrect Access Contro...      NF
# 32  runc is a CLI tool for spawning and running co...      NF
# 33  runc is a CLI tool for spawning and running co...      NF
# 34  The expansion of '\h' in the prompt string in ...     6.0
# 35  Versions of the package cookiejar before 2.1.4...      NF
# 36  A vulnerability classified as problematic has ...     2.7
# 37  A vulnerability was found in the minimatch pac...      NF
# 38  A vulnerability, which was classified as probl...     3.5
# 39  the web framework using ljharb's qs module old...     5.0
# 40  qs before 6.10.3, as used in Express before 4....      NF
# 41  ** UNSUPPORTED WHEN ASSIGNED ** The Request pa...      NF
# 42  Versions of the package semver before 7.5.2 ar...      NF
# 43  The npm package "tar" (aka node-tar) before ve...     5.8
# 44  The npm package "tar" (aka node-tar) before ve...     5.8
# 45  The npm package "tar" (aka node-tar) before ve...     4.4
# 46  The npm package "tar" (aka node-tar) before ve...     4.4
# 47  The npm package "tar" (aka node-tar) before ve...     4.4
# 48  Versions of the package tough-cookie before 4....      NF
# 49  Use of Java's default temporary directory for ...      NF
# 50  The Bzip2 decompression decoder function doesn...     5.0
# 51  The Snappy frame decoder function doesn't rest...     5.0
# 52  Netty is an asynchronous event-driven network ...      NF
# 53  Issue summary: Checking excessively long DH ke...      NF
#
#    v2exploitability v2severity v2impactScore      accessVector  \
# 0               8.6     MEDIUM           6.4           NETWORK
# 1                NF         NF            NF                NF
# 2                NF         NF            NF                NF
# 3                NF         NF            NF                NF
# 4                NF         NF            NF                NF
# 5               8.6     MEDIUM           2.9           NETWORK
# 6                NF         NF            NF                NF
# 7                NF         NF            NF                NF
# 8                NF         NF            NF                NF
# 9                NF         NF            NF                NF
# 10               NF         NF            NF                NF
# 11               NF         NF            NF                NF
# 12               NF         NF            NF                NF
# 13               NF         NF            NF                NF
# 14               NF         NF            NF                NF
# 15               NF         NF            NF                NF
# 16               NF         NF            NF                NF
# 17               NF         NF            NF                NF
# 18               NF         NF            NF                NF
# 19               NF         NF            NF                NF
# 20               NF         NF            NF                NF
# 21               NF         NF            NF                NF
# 22               NF         NF            NF                NF
# 23               NF         NF            NF                NF
# 24               NF         NF            NF                NF
# 25               NF         NF            NF                NF
# 26               NF         NF            NF                NF
# 27               NF         NF            NF                NF
# 28               NF         NF            NF                NF
# 29               NF         NF            NF                NF
# 30               NF         NF            NF                NF
# 31               NF         NF            NF                NF
# 32               NF         NF            NF                NF
# 33               NF         NF            NF                NF
# 34              6.8     MEDIUM           6.4           NETWORK
# 35               NF         NF            NF                NF
# 36              5.1        LOW           2.9  ADJACENT_NETWORK
# 37               NF         NF            NF                NF
# 38              6.8        LOW           2.9           NETWORK
# 39             10.0     MEDIUM           2.9           NETWORK
# 40               NF         NF            NF                NF
# 41               NF         NF            NF                NF
# 42               NF         NF            NF                NF
# 43              8.6     MEDIUM           4.9           NETWORK
# 44              8.6     MEDIUM           4.9           NETWORK
# 45              3.4     MEDIUM           6.4             LOCAL
# 46              3.4     MEDIUM           6.4             LOCAL
# 47              3.4     MEDIUM           6.4             LOCAL
# 48               NF         NF            NF                NF
# 49               NF         NF            NF                NF
# 50             10.0     MEDIUM           2.9           NETWORK
# 51             10.0     MEDIUM           2.9           NETWORK
# 52               NF         NF            NF                NF
# 53               NF         NF            NF                NF
#
#    accessComplexity authentication confidentialityImpact integrityImpact  \
# 0            MEDIUM           NONE               PARTIAL         PARTIAL
# 1                NF             NF                    NF              NF
# 2                NF             NF                    NF              NF
# 3                NF             NF                    NF              NF
# 4                NF             NF                    NF              NF
# 5            MEDIUM           NONE               PARTIAL            NONE
# 6                NF             NF                    NF              NF
# 7                NF             NF                    NF              NF
# 8                NF             NF                    NF              NF
# 9                NF             NF                    NF              NF
# 10               NF             NF                    NF              NF
# 11               NF             NF                    NF              NF
# 12               NF             NF                    NF              NF
# 13               NF             NF                    NF              NF
# 14               NF             NF                    NF              NF
# 15               NF             NF                    NF              NF
# 16               NF             NF                    NF              NF
# 17               NF             NF                    NF              NF
# 18               NF             NF                    NF              NF
# 19               NF             NF                    NF              NF
# 20               NF             NF                    NF              NF
# 21               NF             NF                    NF              NF
# 22               NF             NF                    NF              NF
# 23               NF             NF                    NF              NF
# 24               NF             NF                    NF              NF
# 25               NF             NF                    NF              NF
# 26               NF             NF                    NF              NF
# 27               NF             NF                    NF              NF
# 28               NF             NF                    NF              NF
# 29               NF             NF                    NF              NF
# 30               NF             NF                    NF              NF
# 31               NF             NF                    NF              NF
# 32               NF             NF                    NF              NF
# 33               NF             NF                    NF              NF
# 34           MEDIUM         SINGLE               PARTIAL         PARTIAL
# 35               NF             NF                    NF              NF
# 36              LOW         SINGLE                  NONE            NONE
# 37               NF             NF                    NF              NF
# 38           MEDIUM         SINGLE                  NONE            NONE
# 39              LOW           NONE                  NONE            NONE
# 40               NF             NF                    NF              NF
# 41               NF             NF                    NF              NF
# 42               NF             NF                    NF              NF
# 43           MEDIUM           NONE                  NONE         PARTIAL
# 44           MEDIUM           NONE                  NONE         PARTIAL
# 45           MEDIUM           NONE               PARTIAL         PARTIAL
# 46           MEDIUM           NONE               PARTIAL         PARTIAL
# 47           MEDIUM           NONE               PARTIAL         PARTIAL
# 48               NF             NF                    NF              NF
# 49               NF             NF                    NF              NF
# 50              LOW           NONE                  NONE            NONE
# 51              LOW           NONE                  NONE            NONE
# 52               NF             NF                    NF              NF
# 53               NF             NF                    NF              NF
#
#    availabilityImpact
# 0             PARTIAL
# 1                  NF
# 2                  NF
# 3                  NF
# 4                  NF
# 5                NONE
# 6                  NF
# 7                  NF
# 8                  NF
# 9                  NF
# 10                 NF
# 11                 NF
# 12                 NF
# 13                 NF
# 14                 NF
# 15                 NF
# 16                 NF
# 17                 NF
# 18                 NF
# 19                 NF
# 20                 NF
# 21                 NF
# 22                 NF
# 23                 NF
# 24                 NF
# 25                 NF
# 26                 NF
# 27                 NF
# 28                 NF
# 29                 NF
# 30                 NF
# 31                 NF
# 32                 NF
# 33                 NF
# 34            PARTIAL
# 35                 NF
# 36            PARTIAL
# 37                 NF
# 38            PARTIAL
# 39            PARTIAL
# 40                 NF
# 41                 NF
# 42                 NF
# 43            PARTIAL
# 44            PARTIAL
# 45            PARTIAL
# 46            PARTIAL
# 47            PARTIAL
# 48                 NF
# 49                 NF
# 50            PARTIAL
# 51            PARTIAL
# 52                 NF
# 53                 NF
